# %% [markdown]
# # Average delayed time at Phoenix airport

# %% [markdown]
# The plot below shows the average delay time per month as a function of the increase in temperature, at the Phoenix SKY airport. The data shown only includes flights whose departure was delayed by more than 15 minutes.
#
# From an initial analysis, I found that summer flights have longer delays, and flights in other seasons.
# Below, I plot the average delayed time as a function of the increase of temperature, and fit a linear model to the data, to predict how the delay time will increase if the local temperature keeps increasing. With this data, I find that an increase of 1 Celsius will increase the average delay time by 16 minutes.
#
# This is a preliminary inspection, further analysis is needed to determine how strong is the correlation between delayed times in the summer and temperature increase, and eventually extend the analysis to other airports, where temperatures may not be as extreme as Phoenix.
#
# The data was downloaded from the Bureau of Transportation Statistics (https://www.transtats.bts.gov/ONTIME/Departures.aspx)

# %%
from IPython import display
filename = 'average_delay_time_vs_Dtemp.png'
display.Image(filename)
